# %%
import pandas as pd

# Load the dataset to inspect the structure
file_path = 'data/idosorok.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the data to understand its structure
data.head()
# Out:
#    Column1         SW        KKR        CRWD       GDDY        VST  \
# 0        0  46.220001  53.090000  141.809998  71.430000  28.700001
# 1        1  44.830002  54.919998  144.279999  71.250000  28.820000
# 2        2  45.830002  55.740002  145.089996  73.739998  30.309999
# 3        3  46.869999  55.950001  143.990005  74.150002  30.690001
# 4        4  49.080002  56.000000  146.869995  75.129997  30.139999
#
#          DECK        SMCI       BLDR       UBER  ...         BLK        EW  \
# 0  415.510010   98.519997  65.599998  24.950001  ...  206.000000  7.289167
# 1  439.880005  108.250000  65.309998  24.959999  ...  198.550003  7.341667
# 2  433.290008  112.540001  66.150002  25.360001  ...  199.020004  7.422500
# 3  442.239990  114.000000  65.029999  24.639999  ...  204.559998  7.490000
# 4  442.750000  110.830002  65.300003  24.639999  ...  206.110001  7.456667
#
#        NFLX       FFIV         TT        JCI         CB    KMX       OKE  \
# ...

# %%
import yfinance as yf
import pandas as pd
from datetime import timedelta

# Assuming companies variable contains your JSON with publish and effective dates
companies = [
  {
    "company": "Smurfit WestRock",
    "ticker": "SW",
    "publish_date": "2024-07-08",
    "effective_date": "2024-07-08"
  },
  {
    "company": "CrowdStrike",
    "ticker": "CRWD",
    "publish_date": "2024-06-07",
    "effective_date": "2024-06-24"
  },
  {
    "company": "KKR",
    "ticker": "KKR",
    "publish_date": "2024-06-07",
    "effective_date": "2024-06-24"
  },
  {
    "company": "GoDaddy",
    "ticker": "GDDY",
    "publish_date": "2024-06-07",
    "effective_date": "2024-06-24"
  },
  {
    "company": "Vistra",
    "ticker": "VST",
    "publish_date": "2024-05-03",
    "effective_date": "2024-05-08"
  },
  {
    "company": "GE Vernova",
    "ticker": "GEV",
    "publish_date": "2024-03-27",
    "effective_date": "2024-04-02"
  },
  {
    "company": "Solventum",
    "ticker": "SOLV",
    "publish_date": "2024-03-27",
    "effective_date": "2024-04-01"
  },
  {
    "company": "Deckers Brands",
    "ticker": "DECK",
    "publish_date": "2024-03-01",
    "effective_date": "2024-03-18"
  },
  {
    "company": "Supermicro",
    "ticker": "SMCI",
    "publish_date": "2024-03-01",
    "effective_date": "2024-03-18"
  },
  {
    "company": "Builders FirstSource",
    "ticker": "BLDR",
    "publish_date": "2023-12-01",
    "effective_date": "2023-12-18"
  },
  {
    "company": "Uber",
    "ticker": "UBER",
    "publish_date": "2023-12-01",
    "effective_date": "2023-12-18"
  },
  {
    "company": "Jabil",
    "ticker": "JBL",
    "publish_date": "2023-12-01",
    "effective_date": "2023-12-18"
  },
  {
    "company": "Lululemon Athletica",
    "ticker": "LULU",
    "publish_date": "2023-10-13",
    "effective_date": "2023-10-18"
  },
  {
    "company": "Hubbell",
    "ticker": "HUBB",
    "publish_date": "2023-10-13",
    "effective_date": "2023-10-18"
  },
  {
    "company": "Veralto",
    "ticker": "VLTO",
    "publish_date": "2023-09-28",
    "effective_date": "2023-10-02"
  },
  {
    "company": "Airbnb",
    "ticker": "ABNB",
    "publish_date": "2023-09-01",
    "effective_date": "2023-09-18"
  },
  {
    "company": "Blackstone",
    "ticker": "BX",
    "publish_date": "2023-09-01",
    "effective_date": "2023-09-18"
  },
  {
    "company": "Kenvue",
    "ticker": "KVUE",
    "publish_date": "2023-08-09",
    "effective_date": "2023-08-25"
  },
  {
    "company": "Palo Alto Networks",
    "ticker": "PANW",
    "publish_date": "2023-06-02",
    "effective_date": "2023-06-20"
  },
  {
    "company": "Axon Enterprise",
    "ticker": "AXON",
    "publish_date": "2023-05-01",
    "effective_date": "2023-05-04"
  },
  {
    "company": "Fair Isaac",
    "ticker": "FICO",
    "publish_date": "2023-03-03",
    "effective_date": "2023-03-20"
  },
  {
    "company": "Bunge Limited",
    "ticker": "BG",
    "publish_date": "2023-03-13",
    "effective_date": "2023-03-15"
  },
  {
    "company": "Insulet Corporation",
    "ticker": "PODD",
    "publish_date": "2023-03-10",
    "effective_date": "2023-03-15"
  },
  {
    "company": "GE HealthCare",
    "ticker": "GEHC",
    "publish_date": "2022-12-28",
    "effective_date": "2023-01-04"
  },
  {
    "company": "Steel Dynamics",
    "ticker": "STLD",
    "publish_date": "2022-12-19",
    "effective_date": "2022-12-22"
  },
  {
    "company": "First Solar",
    "ticker": "FSLR",
    "publish_date": "2022-12-12",
    "effective_date": "2022-12-19"
  },
  {
    "company": "Arch Capital Group",
    "ticker": "ACGL",
    "publish_date": "2022-10-27",
    "effective_date": "2022-11-01"
  },
  {
    "company": "Targa Resources",
    "ticker": "TRGP",
    "publish_date": "2022-10-06",
    "effective_date": "2022-10-12"
  },
  {
    "company": "EQT Corporation",
    "ticker": "EQT",
    "publish_date": "2022-09-23",
    "effective_date": "2022-10-03"
  },
  {
    "company": "PG&E Corporation",
    "ticker": "PCG",
    "publish_date": "2022-09-23",
    "effective_date": "2022-10-03"
  },
  {
    "company": "CoStar Group",
    "ticker": "CSGP",
    "publish_date": "2022-09-02",
    "effective_date": "2022-09-19"
  },
  {
    "company": "Invitation Homes",
    "ticker": "INVH",
    "publish_date": "2022-09-02",
    "effective_date": "2022-09-19"
  },
  {
    "company": "Keurig Dr Pepper",
    "ticker": "KDP",
    "publish_date": "2022-06-03",
    "effective_date": "2022-06-21"
  },
  {
    "company": "ON Semiconductor",
    "ticker": "ON",
    "publish_date": "2022-06-03",
    "effective_date": "2022-06-21"
  },
  {
    "company": "VICI Properties",
    "ticker": "VICI",
    "publish_date": "2022-06-03",
    "effective_date": "2022-06-08"
  }
]

# Function to download stock data around the publish date
def download_and_align_data(ticker, publish_date):
    publish_date = pd.to_datetime(publish_date)
    start_date = publish_date - pd.DateOffset(months=12)
    end_date = publish_date + pd.DateOffset(months=2)
    
    # Download stock data from yfinance
    stock_data = yf.download(ticker, start=start_date, end=end_date)
    
    # Ensure there's a 'Close' column
    if 'Close' not in stock_data.columns:
        raise ValueError(f"Data for {ticker} does not contain 'Close' prices.")
    
    # Calculate relative returns by dividing by the publish date's price
    publish_price = stock_data.loc[publish_date, 'Close']
    stock_data['Relative Return'] = stock_data['Close'] / publish_price
    
    # Align the index such that the publish date is considered zero
    stock_data['Days Since Publish'] = (stock_data.index - publish_date).days
    
    return stock_data[['Relative Return', 'Days Since Publish']]

# Dictionary to store aligned data
aligned_data = {}

# Iterate over the companies and process each
for company in companies:
    ticker = company['ticker']
    publish_date = company['publish_date']
    
    try:
        aligned_data[ticker] = download_and_align_data(ticker, publish_date)
        print(f"Successfully downloaded and aligned data for {ticker}")
    except Exception as e:
        print(f"Error downloading data for {ticker}: {e}")

# Now combine all the data into one dataframe for further analysis
combined_data = pd.DataFrame()

# Loop over aligned_data to concatenate the results
for ticker, data in aligned_data.items():
    # Add a column to label the data with the ticker symbol
    data['Ticker'] = ticker
    combined_data = pd.concat([combined_data, data], axis=0)

# The combined_data DataFrame now contains all the aligned data with relative returns and the days since publish
# You can now analyze it, visualize it, or export it.

# Save the combined data to a CSV file
combined_data.to_csv('combined_stock_data.csv', index=False)

# Show the first few rows of combined data
print(combined_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
import matplotlib.pyplot as plt

# Plot each ticker's relative returns aligned to the publish date
plt.figure(figsize=(10, 6))

# Iterate over each ticker and plot its relative return
for ticker in aligned_data:
    data = aligned_data[ticker]
    plt.plot(data['Days Since Publish'], data['Relative Return'], label=ticker)

# Add labels, title, and legend
plt.title('Relative Returns Aligned to Publish Date')
plt.xlabel('Days Since Publish Date')
plt.ylabel('Relative Return (Publish Date = 1)')
plt.axhline(1, color='black', linestyle='--', label='Publish Date (Return = 1)')  # Reference line for publish date
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Function to calculate annualized mean and variance with missing date handling
def calculate_annualized_stats_with_missing_handling(data, publish_date):
    # Resample to ensure continuous dates and fill missing values
    data = data.resample('D').ffill()  # Resample daily and forward-fill missing data

    # Calculate daily returns (percentage change)
    data['Daily Return'] = data['Close'].pct_change()
    
    # Drop rows where Daily Return is NaN (first row after resampling will be NaN)
    data = data.dropna(subset=['Daily Return'])
    
    # Split data into before and after publish date
    before_publish = data[data['Days Since Publish'] < 0]
    after_publish = data[data['Days Since Publish'] >= 0]
    
    # Handle cases where there are no returns before or after the publish date
    if before_publish.empty or after_publish.empty:
        return np.nan, np.nan, np.nan, np.nan

    # Calculate mean and variance of daily returns for each period
    mean_before = before_publish['Daily Return'].mean() * 252  # Annualized mean
    variance_before = before_publish['Daily Return'].var() * 252  # Annualized variance
    
    mean_after = after_publish['Daily Return'].mean() * 252  # Annualized mean
    variance_after = after_publish['Daily Return'].var() * 252  # Annualized variance
    
    return mean_before, variance_before, mean_after, variance_after

# Dictionary to store results
annualized_stats = {}

# Iterate over the tickers and calculate statistics for each
for ticker, data in aligned_data.items():
    try:
        # Make sure to use the publish date for this ticker
        publish_date = data.index[data['Days Since Publish'] == 0][0]  # Find the publish date in the index
        mean_before, var_before, mean_after, var_after = calculate_annualized_stats_with_missing_handling(data, publish_date)
        
        # Store the results
        annualized_stats[ticker] = {
            'mean_before': mean_before,
            'variance_before': var_before,
            'mean_after': mean_after,
            'variance_after': var_after
        }
        print(f"Successfully calculated stats for {ticker}")
    except Exception as e:
        print(f"Error calculating stats for {ticker}: {e}")

# Convert the results into a DataFrame for easy viewing
stats_df = pd.DataFrame(annualized_stats).T

# Display the results
print(stats_df)

# Save the results to a CSV
stats_df.to_csv('annualized_return_stats.csv')
# Out:
# Error calculating stats for SW: 'Close'
# Error calculating stats for CRWD: 'Close'
# Error calculating stats for KKR: 'Close'
# Error calculating stats for GDDY: 'Close'
# Error calculating stats for VST: 'Close'
# Error calculating stats for DECK: 'Close'
# Error calculating stats for SMCI: 'Close'
# Error calculating stats for BLDR: 'Close'
# Error calculating stats for UBER: 'Close'
# Error calculating stats for JBL: 'Close'
# Error calculating stats for LULU: 'Close'
# Error calculating stats for HUBB: 'Close'
# Error calculating stats for ABNB: 'Close'
# Error calculating stats for BX: 'Close'
# Error calculating stats for KVUE: 'Close'
# Error calculating stats for PANW: 'Close'
# Error calculating stats for AXON: 'Close'
# Error calculating stats for FICO: 'Close'
# Error calculating stats for BG: 'Close'
# Error calculating stats for PODD: 'Close'
# Error calculating stats for GEHC: 'Close'
# Error calculating stats for FSLR: 'Close'
# ...

# %%
import matplotlib.pyplot as plt

# Normalize the data by dividing by the first row (initial values for each stock)
normalized_data = data.iloc[:, 1:].div(data.iloc[0, 1:], axis=1)

# Plotting the relative time series for a subset of stocks (e.g., first 10 tickers)
plt.figure(figsize=(14, 8))
for column in normalized_data.columns[:10]:  # Taking only the first 10 columns for clarity
    plt.plot(normalized_data.index, normalized_data[column], label=column)

plt.title('Relative Stock Price Movements (First 10 Tickers)')
plt.xlabel('Time')
plt.ylabel('Relative Price (Normalized)')
plt.legend(loc='upper left')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\takat\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#
# File c:\Users\takat\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File c:\Users\takat\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\computation\expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# ...

# %%
# Define the number of trading days per month (21 days as an approximation)
trading_days_per_month = 21
n=10
# k=
# Calculate the number of days for n=6 months and k=3 months
n_days = n * trading_days_per_month
k_days = 10
results = []
# Forward-fill missing values to handle potential gaps in the data
data_cleaned = data.fillna(method='ffill')
for i in range(0, 7*trading_days_per_month):
    n_days += 1
    if n_days+k_days >= len(data_cleaned):
        break
    # Split the data into the first n months and last k months
    first_n_months_data = data_cleaned.iloc[:n_days]
    last_k_months_data = data_cleaned.iloc[n_days: n_days+k_days]

    # Calculate returns for each stock
    # The return is calculated as (end_price - start_price) / start_price
    first_n_months_returns = (first_n_months_data.iloc[-1] - first_n_months_data.iloc[0]) / first_n_months_data.iloc[0]
    last_k_months_returns = (last_k_months_data.iloc[-1] - last_k_months_data.iloc[0]) / last_k_months_data.iloc[0]

    # Annualize the returns assuming 252 trading days per year
    annualized_first_n_returns = (1 + first_n_months_returns) ** (252 / n_days) - 1
    annualized_last_k_returns = (1 + last_k_months_returns) ** (252 / k_days) - 1

    # Drop the 'Column1' which is an index column not related to stocks
    annualized_first_n_returns = annualized_first_n_returns.drop('Column1', errors='ignore')
    annualized_last_k_returns = annualized_last_k_returns.drop('Column1', errors='ignore')

    # Combine the results into a DataFrame for better visualization
    returns_df = pd.DataFrame({
        'Annualized Return (First n months)': annualized_first_n_returns,
        'Annualized Return (Last k months)': annualized_last_k_returns
    })

    results.append(returns_df.mean())
# Out:
# C:\Users\takat\AppData\Local\Temp\ipykernel_17076\2299328743.py:10: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data_cleaned = data.fillna(method='ffill')

# %%
import matplotlib.pyplot as plt

# Sample data from the user

# Convert the data into a DataFrame for easy plotting
df_samples = pd.DataFrame(results)

# Create a plot comparing the first n months and last k months' annualized returns
plt.figure(figsize=(8, 6))
plt.plot(df_samples['Annualized Return (First n months)'], label='First n months')
plt.plot(df_samples['Annualized Return (Last k months)'], label='Last k months', linestyle='--')

# Adding labels and title
plt.title('Comparison of Annualized Returns for First n and Last k Months')
plt.xlabel('Sample Index')
plt.ylabel('Annualized Return')
plt.legend()

# Show plot
plt.show()
